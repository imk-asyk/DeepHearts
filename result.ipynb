# %%
import torch
from models import *
from game import GAME
#from llm import llm, TEXT
from multiprocessing import Pool
from tqdm import tqdm
from dspGuru import HeartsAIPlayer as H
#import os

'''
no_llm = True
if not no_llm:
    if 'y' in input('Local llm is very slow. Proceed? y/N').lower():
        qwen_size = '0.6' # or '8' or '32'
        qwen = llmPlayer(llm(os.path.join(
            os.environ['USERPROFILE'], f'.cache/modelscope/hub/models/Qwen/Qwen3-{qwen_size}B')))
        qwen.ai(TEXT)
'''

GAME.lr = None

def autoplay(players, times=10000000, mp=10000):
    GAME.players = players
    with torch.no_grad():
        if mp:
            with Pool(20) as pool:
                return sum(sum(pool.map(GAME, range(mp))) for i in tqdm(range(times // mp))) / times
        return sum(GAME(i) for i in tqdm(range(times))) / times

def main():
    PLAYER = DeepHearts()
    PLAYER.model.load_state_dict(torch.load('hearts_ai.pth'))
    PLAYER.model.eval()
    for j in [H(0), RANDOM_PLAYER, PLAYER]:
        for k in [[H(1), H(2), H(3)], [RANDOM_PLAYER] * 3, [PLAYER] * 3]:
            print(j.__class__.__name__, '1v3', k[0].__class__.__name__, autoplay([j] + k))
            k[1] = H(2) if j.__class__.__name__ == 'HeartsAI' else j
            print(j.__class__.__name__, '2v2', k[0].__class__.__name__, autoplay([j] + k))

if __name__ == '__main__':
    main()
# Out:
# 100%|██████████| 1000/1000 [23:41<00:00,  1.42s/it]
# HeartsAIPlayer 1v3 HeartsAIPlayer tensor([6.8296, 6.8257, 6.8310, 6.8290])
# 100%|██████████| 1000/1000 [24:04<00:00,  1.44s/it]
# HeartsAIPlayer 2v2 HeartsAIPlayer tensor([6.8271, 6.8269, 6.8308, 6.8276])
# 100%|██████████| 1000/1000 [09:55<00:00,  1.68it/s]
# HeartsAIPlayer 1v3 RandomModel tensor([2.4515, 8.0538, 8.0623, 8.0489])
# 100%|██████████| 1000/1000 [14:35<00:00,  1.14it/s]
# HeartsAIPlayer 2v2 RandomModel tensor([ 3.3367, 10.1119,  3.3351, 10.1094])
# 100%|██████████| 1000/1000 [5:15:44<00:00, 18.94s/it]
# HeartsAIPlayer 1v3 DeepHearts tensor([8.0379, 6.1617, 6.2491, 6.5015])
# 100%|██████████| 1000/1000 [3:35:41<00:00, 12.94s/it]
# HeartsAIPlayer 2v2 DeepHearts tensor([7.2718, 6.1836, 7.2706, 6.2008])
# 100%|██████████| 1000/1000 [19:19<00:00,  1.16s/it]
# RandomModel 1v3 HeartsAIPlayer tensor([12.7285,  5.0555,  5.1183,  5.1295])
# 100%|██████████| 1000/1000 [14:33<00:00,  1.14it/s]
# RandomModel 2v2 HeartsAIPlayer tensor([10.1076,  3.3339, 10.1110,  3.3396])
# 100%|██████████| 1000/1000 [06:07<00:00,  2.72it/s]
# RandomModel 1v3 RandomModel tensor([6.6394, 6.6424, 6.6423, 6.6408])
# 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
# RandomModel 2v2 RandomModel tensor([6.6428, 6.6383, 6.6423, 6.6433])
# 100%|██████████| 1000/1000 [4:44:32<00:00, 17.07s/it]
# RandomModel 1v3 DeepHearts tensor([13.7621,  4.7613,  4.7494,  4.7984])
# 100%|██████████| 1000/1000 [3:43:41<00:00, 13.42s/it]
# RandomModel 2v2 DeepHearts tensor([10.4802,  3.1614, 10.4898,  3.1622])
# 100%|██████████| 1000/1000 [1:29:52<00:00,  5.39s/it]
# DeepHearts 1v3 HeartsAIPlayer tensor([6.5845, 7.0039, 6.7465, 6.7064])
# 100%|██████████| 1000/1000 [3:23:13<00:00, 12.19s/it]
# DeepHearts 2v2 HeartsAIPlayer tensor([6.2112, 7.2603, 6.2102, 7.2406])
# 100%|██████████| 1000/1000 [1:40:10<00:00,  6.01s/it]
# DeepHearts 1v3 RandomModel tensor([2.1461, 8.1929, 8.2262, 8.2947])
# 100%|██████████| 1000/1000 [3:10:01<00:00, 11.40s/it]
# DeepHearts 2v2 RandomModel tensor([ 3.1591, 10.4909,  3.1529, 10.4759])
# 100%|██████████| 1000/1000 [7:01:44<00:00, 25.30s/it]
# DeepHearts 1v3 DeepHearts tensor([6.7109, 6.7032, 6.7020, 6.7009])
# 100%|██████████| 1000/1000 [6:46:25<00:00, 24.39s/it]
# DeepHearts 2v2 DeepHearts tensor([6.7156, 6.6958, 6.7036, 6.7032])
